# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')

#df= pd.DataFrame(dataset['train'])
both are same
df= dataset['train'].to_pandas()

# %%
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_salary = df[pd.notna(df['salary_year_avg'])]

# %%
df_salary
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
def salary_projected(salary):
    return salary * 1.03;

df_salary['salary_inflated'] =df_salary['salary_year_avg'].apply(salary_projected)

df_salary[['salary_year_avg', 'salary_inflated']]
# Out:
# /var/folders/tm/n04439ts2c1gj_0tqdrrz6jr0000gn/T/ipykernel_69209/154481823.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary['salary_inflated'] =df_salary['salary_year_avg'].apply(salary_projected)
#         salary_year_avg  salary_inflated
# 28             109500.0        112785.00
# 77             140000.0        144200.00
# 92             120000.0        123600.00
# 100            228222.0        235068.66
# 109             89000.0         91670.00
# ...                 ...              ...
# 785624         139216.0        143392.48
# 785641         150000.0        154500.00
# 785648         221875.0        228531.25
# 785682         157500.0        162225.00
# 785692         157500.0        162225.00
#
# ...

# %%
df_salary['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df_salary['salary_inflated'] =df_salary['salary_year_avg'].apply(lambda x: x * 1.08)

df_salary[['salary_year_avg', 'salary_inflated']]
# Out:
# /var/folders/tm/n04439ts2c1gj_0tqdrrz6jr0000gn/T/ipykernel_69209/881757921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary['salary_inflated'] =df_salary['salary_year_avg'].apply(lambda x: x * 1.08)
#         salary_year_avg  salary_inflated
# 28             109500.0        118260.00
# 77             140000.0        151200.00
# 92             120000.0        129600.00
# 100            228222.0        246479.76
# 109             89000.0         96120.00
# ...                 ...              ...
# 785624         139216.0        150353.28
# 785641         150000.0        162000.00
# 785648         221875.0        239625.00
# 785682         157500.0        170100.00
# 785692         157500.0        170100.00
#
# ...

# %%
df_salary['salary_inflated']= df_salary['salary_year_avg'].apply(lambda x: x * 1.08 if pd.notna(x) else x)
df_salary[['salary_year_avg', 'salary_inflated']]
# Out:
# /var/folders/tm/n04439ts2c1gj_0tqdrrz6jr0000gn/T/ipykernel_69209/2391470802.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary['salary_inflated']= df_salary['salary_year_avg'].apply(lambda x: x * 1.08 if pd.notna(x) else x)
#         salary_year_avg  salary_inflated
# 28             109500.0        118260.00
# 77             140000.0        151200.00
# 92             120000.0        129600.00
# 100            228222.0        246479.76
# 109             89000.0         96120.00
# ...                 ...              ...
# 785624         139216.0        150353.28
# 785641         150000.0        162000.00
# 785648         221875.0        239625.00
# 785682         157500.0        170100.00
# ...

# %%
df['salary_inflated']= df['salary_year_avg']*1.04

# %%
type(df['job_skills'][1])
# Out:
# str

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
list = df['job_skills'].to_list()[1]

# %%
type(list)
# Out:
# str

# %%
import ast

# %%
ast.literal_eval(df['job_skills'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 ast.literal_eval(df['job_skills'])
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# ...

# %%
def parse_skills(skills):
    try:
        if pd.notna(skills):
            return ast.literal_eval(skills)
    except (ValueError, SyntaxError):
        return []

df['parsed_skills'] = df['job_skills'].apply(parse_skills)

# %%
type(df['parsed_skills'])
# Out:
# pandas.core.series.Series

# %%
type(df['parsed_skills'][0])
# Out:
# list

# %%
df[pd.isna(df['parsed_skills'])]
# Out:
# Empty DataFrame
# Columns: [job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills, salary_inflated, parsed_skills]
# Index: []

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['parsed_skills']= df['parsed_skills'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
df['parsed_skills']
# Out:
# 0                                                        []
# 1                [r, python, sql, nosql, power bi, tableau]
# 2         [python, sql, c#, azure, airflow, dax, docker,...
# 3         [python, c++, java, matlab, aws, tensorflow, k...
# 4         [bash, python, oracle, aws, ansible, puppet, j...
#                                 ...
# 785736    [bash, python, perl, linux, unix, kubernetes, ...
# 785737                               [sas, sas, sql, excel]
# 785738                                  [powerpoint, excel]
# 785739    [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                          [aws, flow]
# Name: parsed_skills, Length: 785741, dtype: object

# %%
df_salary['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
def projectsal(row):
    if "Senior" in df_salary['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']


df_salary['salary_inflated']= df_salary.apply(projectsal, axis=1)


df_salary[['job_title_short','salary_year_avg', 'salary_inflated']]
# Out:
# /var/folders/tm/n04439ts2c1gj_0tqdrrz6jr0000gn/T/ipykernel_69209/209214969.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary['salary_inflated']= df_salary.apply(projectsal, axis=1)
#        job_title_short  salary_year_avg  salary_inflated
# 28      Data Scientist         109500.0        112785.00
# 77       Data Engineer         140000.0        144200.00
# 92       Data Engineer         120000.0        123600.00
# 100     Data Scientist         228222.0        235068.66
# 109       Data Analyst          89000.0         91670.00
# ...                ...              ...              ...
# 785624   Data Engineer         139216.0        143392.48
# 785641   Data Engineer         150000.0        154500.00
# ...
