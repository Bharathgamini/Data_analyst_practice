# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset


dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df.head
# Out:
# <bound method NDFrame.head of              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# ...

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.pivot_table(values='salary_year_avg',index='job_title_short', aggfunc='median').sort_values(by='salary_year_avg', ascending=False).head(10)  .plot(kind='barh')
plt.xlabel('Median Yearly Salary')
plt.title('Top 10 Job Titles by Median Yearly Salary')
# Out:
# Text(0.5, 1.0, 'Top 10 Job Titles by Median Yearly Salary')

# %%
df.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short', aggfunc='median').head(10)
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# Austria                       NaN             NaN      80850.00
# Azerbaijan                    NaN             NaN           NaN
# Bahamas                       NaN             NaN           NaN
# Bangladesh                16500.0             NaN           NaN
# Belarus                       NaN             NaN     400000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# Algeria                45000.0             NaN                        NaN
# ...

# %%
top_countries = df['job_country'].value_counts().nlargest(5).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany'], dtype='object', name='job_country')

# %%
df_job_country_salary = df.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short', aggfunc='median')

df_job_country_salary = df_job_country_salary.loc[top_countries]

# %%
job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']

# %%
df_job_country_salary = df_job_country_salary[job_titles]

# %%
df_job_country_salary
# Out:
# job_title_short  Data Scientist  Data Engineer  Machine Learning Engineer  \
# job_country
# United States          130000.0       125000.0                   150000.0
# India                  114008.0       147500.0                    79200.0
# United Kingdom         105300.0       110000.0                   149653.0
# France                  88128.0        98301.5                    80850.0
# Germany                131560.0       147500.0                    89100.0
#
# job_title_short  Data Analyst
# job_country
# United States         90000.0
# India                100500.0
# United Kingdom        87750.0
# France                69175.0
# Germany              103750.0

# %%
df_job_country_salary.plot(kind='bar')
plt.xlabel('Median Yearly Salary by Country')
plt.ylabel('Median Yearly Salary in USD')
plt.title('Median Yearly Salary by Job Title and Country')
plt.legend(title='Job Title')
plt.xticks(rotation=45, ha = 'right')
plt.tight_layout()
plt.show()

# %%
df_usa = df[df['job_country'] == 'United States']

# %%
df_usa.head()
# Out:
#    Usa_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# ...

# %%
df_usa.index.name= 'Usa_index'

# %%
df_usa.reset_index(inplace=True)

# %%
df_usa.head()
# Out:
#    Usa_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# ...

# %%
df_usa.index
# Out:
# RangeIndex(start=0, stop=206292, step=1)

# %%
median_values = df_usa.pivot_table(values='salary_year_avg',index='job_title_short', aggfunc=['mean', 'median', 'max', 'min'])

# %%
median_values
# Out:
#                                      mean          median             max  \
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst             96175.447397         90000.0        387460.0
# Cloud Engineer              120090.900000        116100.0        221844.0
# Data Analyst                 94553.964924         90000.0        375000.0
# Data Engineer               134226.676753        125000.0        525000.0
# Data Scientist              139946.707204        130000.0        960000.0
# Machine Learning Engineer   154240.382812        150000.0        315000.0
# Senior Data Analyst         115729.129954        110000.0        425000.0
# Senior Data Engineer        151448.023186        150000.0        375000.0
# Senior Data Scientist       159330.432029        155000.0        475000.0
# Software Engineer           137964.929588        130000.0        375000.0
#
#                                       min
# ...

# %%
df_usa
# Out:
#         Usa_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df_drop = df_usa

# %%
df_drop
# Out:
#         Usa_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df.job_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tm/n04439ts2c1gj_0tqdrrz6jr0000gn/T/ipykernel_54516/3501908120.py in ?()
# ----> 1 df.job_id
#
# /opt/anaconda3/envs/python_data_jobs/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'job_id'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df_drop = df.set_index(df.index, inplace=True)

# %%
df_drop.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df_drop.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
df_drop

# %%
df_usa
# Out:
#         Usa_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df_drop = df_usa

# %%
df_drop
# Out:
#         Usa_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df_drop = df_drop.set_index('Usa_index')

# %%
df_drop
# Out:
#                 job_title_short  \
# Usa_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# Usa_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
median_values
# Out:
#                                      mean          median             max  \
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst             96175.447397         90000.0        387460.0
# Cloud Engineer              120090.900000        116100.0        221844.0
# Data Analyst                 94553.964924         90000.0        375000.0
# Data Engineer               134226.676753        125000.0        525000.0
# Data Scientist              139946.707204        130000.0        960000.0
# Machine Learning Engineer   154240.382812        150000.0        315000.0
# Senior Data Analyst         115729.129954        110000.0        425000.0
# Senior Data Engineer        151448.023186        150000.0        375000.0
# Senior Data Scientist       159330.432029        155000.0        475000.0
# Software Engineer           137964.929588        130000.0        375000.0
#
#                                       min
# ...

# %%
median_values.sort_values(by=('median', 'salary_year_avg'), ascending=False)
# Out:
#                                      mean          median             max  \
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist       159330.432029        155000.0        475000.0
# Machine Learning Engineer   154240.382812        150000.0        315000.0
# Senior Data Engineer        151448.023186        150000.0        375000.0
# Data Scientist              139946.707204        130000.0        960000.0
# Software Engineer           137964.929588        130000.0        375000.0
# Data Engineer               134226.676753        125000.0        525000.0
# Cloud Engineer              120090.900000        116100.0        221844.0
# Senior Data Analyst         115729.129954        110000.0        425000.0
# Business Analyst             96175.447397         90000.0        387460.0
# Data Analyst                 94553.964924         90000.0        375000.0
#
#                                       min
# ...

# %%
median_values.sort_index(inplace=True)

# %%
median_values
# Out:
#                                      mean          median             max  \
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst             96175.447397         90000.0        387460.0
# Cloud Engineer              120090.900000        116100.0        221844.0
# Data Analyst                 94553.964924         90000.0        375000.0
# Data Engineer               134226.676753        125000.0        525000.0
# Data Scientist              139946.707204        130000.0        960000.0
# Machine Learning Engineer   154240.382812        150000.0        315000.0
# Senior Data Analyst         115729.129954        110000.0        425000.0
# Senior Data Engineer        151448.023186        150000.0        375000.0
# Senior Data Scientist       159330.432029        155000.0        475000.0
# Software Engineer           137964.929588        130000.0        375000.0
#
#                                       min
# ...
