# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset


dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')

# %%
#i want to do jobtrndds for only us
df_us = df[df['job_country']=='United States'].copy()

# %%
print(id(df_us))
print(id(df))
# Out:
# 5478030288
# 5477311424

# %%
#
# df['job_posted_month']= df['job_posted_date'].dt.to_period('M'))

# %%
df_us['job_posted_month']= df_us['job_posted_date'].dt.strftime('%B')

# %%
df_us['job_posted_month']
# Out:
# 0             June
# 3             July
# 5         November
# 6            March
# 9            April
#             ...
# 785673     October
# 785685        July
# 785692       April
# 785703     January
# 785705     January
# Name: job_posted_month, Length: 206292, dtype: object

# %%
df_us_pivot=df_us.pivot_table(index='job_posted_month',values='salary_year_avg' ,columns='job_title_short', aggfunc='size')

# %%
df_us_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_us_pivot.reset_index(inplace=True)

# %%
df_us_pivot['month_no'] = pd.to_datetime(df_us_pivot['job_posted_month'], format='%B').dt.month

# %%
df_us_pivot['job_posted_month']
# Out:
# month_no
# 1       January
# 2      February
# 3         March
# 4         April
# 5           May
# 6          June
# 7          July
# 8        August
# 9     September
# 10      October
# 11     November
# 12     December
# Name: job_posted_month, dtype: object

# %%
df_us_pivot['month_no']
# Out:
# 0      4
# 1      8
# 2     12
# 3      2
# 4      1
# 5      7
# 6      6
# 7      3
# 8      5
# 9     11
# 10    10
# 11     9
# Name: month_no, dtype: int32

# %%
df_us_pivot.set_index('month_no', inplace=True)

# %%
df_us_pivot.sort_values('month_no', inplace=True)

# %%
df_us_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# month_no
# 1                        January               527              36
# 2                       February               447              24
# 3                          March               438              19
# 4                          April               565              40
# 5                            May               279              20
# 6                           June               446              32
# 7                           July               581              39
# 8                         August               903              39
# 9                      September               897              50
# 10                       October               932              48
# 11                      November               719              36
# 12                      December               648              40
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# month_no
# ...

# %%
df_us_pivot.set_index('job_posted_month', inplace=True)

# %%
df_us_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_us_pivot[top3].plot(kind='bar', figsize=(12, 6))
plt.title('Job Postings by Month and Job Title in the US')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_us_pivot.plot(kind='line', figsize=(12, 6))
plt.title('Job Postings by Month and Job Title in the US')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
top3 = df_us['job_title_short'].value_counts().nlargest(3).index
top3
# Out:
# Index(['Data Analyst', 'Data Scientist', 'Data Engineer'], dtype='object', name='job_title_short')

# %%
top3.head()
# Out:
# job_title_short
# Data Analyst      67816
# Data Scientist    58830
# Data Engineer     35080
# Name: count, dtype: int64

# %%
df_us_pivot[top3].plot(kind='line', figsize=(12, 6))
plt.title('Top 3 Job Postings by Month in the US')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_jobs = pd.read_csv('https://lukeb.co/software_csv')

# %%
df_merge  = df_us_pivot.merge(df_jobs, on = 'job_posted_month', how='left')

# %%
df_merge
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
top_5 = (df_merge.sum().sort_values(ascending=False).head().index.to_list())

top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'Data Analyst',
#  'Data Scientist']

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, January to December
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Business Analyst           12 non-null     int64
#  1   Cloud Engineer             12 non-null     int64
#  2   Data Analyst               12 non-null     int64
#  3   Data Engineer              12 non-null     int64
#  4   Data Scientist             12 non-null     int64
#  5   Machine Learning Engineer  12 non-null     int64
#  6   Senior Data Analyst        12 non-null     int64
#  7   Senior Data Engineer       12 non-null     int64
#  8   Senior Data Scientist      12 non-null     int64
#  9   Software Engineer          12 non-null     int64
#  10  Front-End Developer        12 non-null     int64
#  11  Back-End Developer         12 non-null     int64
#  12  Full-Stack Developer       12 non-null     int64
# ...

# %%
df_merge['Cloud Engineer'].sum()
# Out:
# np.int64(423)

# %%
top_5.index.to_list()
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'Data Analyst',
#  'Data Scientist']

# %%
df_merge[top_5].plot(kind='line')
plt.title('Job Postings by Month and Job Title in the US')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_merge[top_5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df_merge[top_5]
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
df_merge[top_5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df_merge[top_5]
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_job_jan = df

# %%
df_job_jan
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_job_jan['job_posted_month']= df_us['job_posted_date'].dt.strftime('%B')

# %%
df_job_jan
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_job_jan.dropna()
# Out:
# Empty DataFrame
# Columns: [job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills, job_posted_month]
# Index: []

# %%
df['job_posted_month']=df_job_jan['job_posted_month'].dropna(inplace=True)

# %%
df_job_jan
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_job_jan = df_job_jan.dropna(subset=['job_posted_month'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_job_jan
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_job_jan= df_job_jan[df_job_jan['job_posted_month']=='January']

# %%
df_job_jan
# Out:
#             job_title_short                                  job_title  \
# 39            Data Engineer                              Data Engineer
# 53            Data Engineer                              Data Engineer
# 60         Business Analyst               Business Intelligence Intern
# 61            Data Engineer                              Data Engineer
# 155            Data Analyst                               Data Analyst
# ...                     ...                                        ...
# 785625  Senior Data Analyst                        Senior Data Analyst
# 785641        Data Engineer                              Data Engineer
# 785651       Data Scientist     Data Scientist (Supply Chain Security)
# 785703         Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785705         Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                job_location          job_via job_schedule_type  \
# ...

# %%
df_job_feb = df

# %%
df_job_feb['job_posted_month'] = df_job_feb['job_posted_date'].dt.strftime('%B')

# %%
df_job_feb['job_posted_month']= df_job_feb['job_posted_month'].dropna()

# %%
df_job_feb
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_job_feb = df_job_feb[df_job_feb['job_posted_month']=='February']

# %%
df_job_feb
# Out:
#              job_title_short  \
# 21            Data Scientist
# 27             Data Engineer
# 34              Data Analyst
# 35             Data Engineer
# 62            Data Scientist
# ...                      ...
# 784588         Data Engineer
# 784779  Senior Data Engineer
# 784994     Software Engineer
# 785142      Business Analyst
# 785402     Software Engineer
#
#                                                 job_title  \
# 21      Stage - data scientist – génération ia de donn...
# 27      Principal Data Engineer (Lead), Knowledge Grap...
# 34      Data Analyst als Marketing Manager Automation ...
# 35                            Data Engineer - Royal Canin
# 62                                         Data Scientist
# ...                                                   ...
# 784588                                      Data Engineer
# 784779                  Senior Data Engineer - SQL/Python
# 784994                    Microsoft Dynamics CRM Engineer
# ...

# %%
dict_months = {
    'January': df_job_jan,
    'February': df_job_feb,
    'March':df_job_mar,
    'April':df_job_apr,
    'May':df_job_may,
    'June':df_job_jun,
    'july':df_job_jul,
    'august':df_job_aug,
    'September':df_job_sep,
    'October':df_job_oct,
    'November':df_job_nov,
    'December':df_job_dec
}

# %%
months = df['job_posted_month'].unique()
months
# Out:
# array(['June', 'January', 'October', 'July', 'August', 'November',
#        'March', 'December', 'April', 'February', 'September', 'May'],
#       dtype=object)

# %%
dict_month={month: df[df['job_posted_month']==month] for month in months}

# %%
dict_month['January']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
df_q1 = pd.concat([dict_month['January'], dict_month['February'], dict_month['March']], ignore_index=True)

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
#!/usr/bin/env python3
plt.ylabel('Number of Job Postings')
plt.title('Job Postings in Q1 by Month')
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_q1.head().to_clipboard(sep = ',')

# %%
,job_title_short,job_title,job_location,job_via,job_schedule_type,job_work_from_home,search_location,job_posted_date,job_no_degree_mention,job_health_insurance,job_country,salary_rate,salary_year_avg,salary_hour_avg,company_name,job_skills,job_type_skills,job_posted_month
0,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,,,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}",January
1,Data Scientist,Data Scientist,"Zaventem, Belgium",via BeBee Belgique,Full-time,False,Belgium,2023-01-31 13:53:38,False,False,Belgium,,,,Devoteam,"['r', 'python', 'sql', 'pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark']","{'libraries': ['pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark'], 'programming': ['r', 'python', 'sql']}",January
2,Data Engineer,Data Engineer,"Fort Worth, TX",via LinkedIn,Full-time,False,"Texas, United States",2023-01-25 13:24:01,False,False,United States,,,,Programmers.io,"['sql', 'python']","{'programming': ['sql', 'python']}",January
3,Data Engineer,Data Engineer,"San Mateo, CA",via LinkedIn,Full-time,False,"California, United States",2023-01-28 13:07:30,False,True,United States,,,,Verkada,"['sql', 'python', 'aws', 'looker']","{'analyst_tools': ['looker'], 'cloud': ['aws'], 'programming': ['sql', 'python']}",January
4,Data Scientist,Data Scientist,"São Paulo, State of São Paulo, Brazil",via BeBee,Full-time,False,Brazil,2023-01-03 23:02:27,False,False,Brazil,,,,Mars,"['python', 'sql', 'azure']","{'cloud': ['azure'], 'programming': ['python', 'sql']}",January
# Out:
#   Cell In[144], line 2
#     0,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,,,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}",January
#                                                                                                              ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
df_q1.to_csv('job_postings_q1.csv', index=False)

# %%
df_read = pd.read_csv('job_postings_q1.csv')

# %%
df_read
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...
