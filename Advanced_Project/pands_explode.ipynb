# %%
import pandas as pd

data = {
    'job_skills': [['Python', 'Pandas', 'SQL'],
                   ['Java', 'Spring', 'Hibernate'],
                   None,
                   ['JavaScript', 'React', 'Node.js'],
                   ['C++', 'Qt', 'Boost']],
    'job_title_short': ['Data Scientist',  'Data Analyst',  'Sr. Data Analyst', 'Data engineer', 'ML Engineer']
}

# %%
df_skills_lists = pd.DataFrame(data)

# %%
df_skills_lists
# Out:
#                      job_skills   job_title_short
# 0         [Python, Pandas, SQL]    Data Scientist
# 1     [Java, Spring, Hibernate]      Data Analyst
# 2                          None  Sr. Data Analyst
# 3  [JavaScript, React, Node.js]     Data engineer
# 4              [C++, Qt, Boost]       ML Engineer

# %%
df_skills_lists[['job_title_short', 'job_skills']]
# Out:
#     job_title_short                          job_skills
# 0    Data Scientist         ['Python', 'Pandas', 'SQL']
# 1      Data Analyst     ['Java', 'Spring', 'Hibernate']
# 2  Sr. Data Analyst                                None
# 3     Data engineer  ['JavaScript', 'React', 'Node.js']
# 4       ML Engineer              ['C++', 'Qt', 'Boost']

# %%
df_skills_lists.value_counts('job_skills')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_skills_lists.value_counts('job_skills')
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/site-packages/pandas/core/frame.py:7516, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7513     subset = self.columns.tolist()
#    7515 name = "proportion" if normalize else "count"
# -> 7516 counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7517 counts.name = name
#    7519 if sort:
#
# File /opt/anaconda3/envs/python_data_jobs/lib/python3.13/site-packages/pandas/core/groupby/ops.py:705, in BaseGrouper.size(self)
#     700 @final
#     701 def size(self) -> Series:
#     702     """
#     703     Compute group sizes.
#     704     """
# --> 705     ids, _, ngroups = self.group_info
#     706     out: np.ndarray | list
# ...

# %%
df_skills_lists.explode('job_skills').value_counts('job_skills').plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset


dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()


df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else x)

# %%
df_exploded = df.explode('job_skills')

# %%
type(df['job_skills'][0])
# Out:
# NoneType

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
import ast

# %%
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else x)

# %%
df['job_skills']
# Out:
# 0                                                      None
# 1                [r, python, sql, nosql, power bi, tableau]
# 2         [python, sql, c#, azure, airflow, dax, docker,...
# 3         [python, c++, java, matlab, aws, tensorflow, k...
# 4         [bash, python, oracle, aws, ansible, puppet, j...
#                                 ...
# 785736    [bash, python, perl, linux, unix, kubernetes, ...
# 785737                               [sas, sas, sql, excel]
# 785738                                  [powerpoint, excel]
# 785739    [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                          [aws, flow]
# Name: job_skills, Length: 785741, dtype: object

# %%
df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
skills_count = df_exploded.groupby(['job_title_short','job_skills']).size()

type(skills_count)
# Out:
# pandas.core.series.Series

# %%
df_skills_count = skills_count.reset_index(name='counts')

type(df_skills_count)
# Out:
# pandas.core.frame.DataFrame

# %%
df_skills_count = df_skills_count.sort_values(by='counts', ascending=False).head(10)
df_skills_count
#df_skills_count.head(10).plot(kind='barh', x='job_skills', y='counts')
# Out:
#      job_title_short job_skills  counts
# 1066  Data Scientist     python  113711
# 865    Data Engineer        sql  113130
# 830    Data Engineer     python  108022
# 625     Data Analyst        sql   92428
# 1101  Data Scientist        sql   78982
# 494     Data Analyst      excel   66860
# 686    Data Engineer        aws   62049
# 687    Data Engineer      azure   60674
# 1070  Data Scientist          r   59566
# 590     Data Analyst     python   57190

# %%
job_title = 'Data Engineer'
top_skills = 10

df_skill_final = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)

df_skill_final
# Out:
#     job_title_short job_skills  counts
# 865   Data Engineer        sql  113130
# 830   Data Engineer     python  108022
# 686   Data Engineer        aws   62049
# 687   Data Engineer      azure   60674

# %%
job_title = 'Data Engineer'
top_skills = 10

df_skill_final = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)

df_skill_final

df_skill_final.plot(kind='barh', x='job_skills', y='counts' )
plt.title(f'Top {top_skills} skills for {job_title}')
#plt.gca().invert_yaxis()
plt.gca().set_ylabel('Counts')
plt.gca().set_xlabel('Job Skills')
plt.legend().remove()
plt.show()
